# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np

# %%
# Categorical plot
# x axis is categorical
# y is numberical
# barplot will show avg (default) of each categorical data
# can pass any aggregate function to estimator argument
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
tips.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
# show count of occurance of each categorical data in df
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# x is categorical, y is numerical
# show quatile of df
sns.boxplot(x='day',y='total_bill',data=tips)

# can also add another categorical by using hue ='', such as smoker
# sns.boxplot(x='day',y='total_bill',data=tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# look like boxplot
# we can use split=True when we would like to see the different between two hue
# easier to understand
sns.violinplot(x='day',y='total_bill', data=tips, hue='sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# same as scatter plot
# use jitter=True to improve the density of dots -> easy to see
# dodge is same as split
sns.stripplot(x='day',y='total_bill',data=tips, jitter=True, hue='sex', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# combination of violinplot and stripplot
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips, color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.factorplot(x='day', y='total_bill', data=tips, kind='violin')
# Out:
# /Users/boyplus/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
