# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# df2 contains only 9 rows
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
# the x axis will be categorical
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
# x axis is categorical
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# This code does not work anymore
# df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)

# %%
# df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
df1.plot.scatter(x='A',y='B',s=df1['C']*20)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
# random number to be an array of 4 rows 5 columns
np.random.randn(4,5)
# Out:
# array([[-1.7303783 , -0.0227936 ,  0.24894052,  3.047497  , -1.18596634],
#        [-1.48372075, -1.29108938, -1.62503206,  1.81723936,  0.51188325],
#        [ 0.04958853,  1.30580595, -0.50692735, -0.72160341,  0.61217073],
#        [-0.3833425 ,  1.23114861,  0.82342778, -1.30275853, -1.09009712]])

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  1.191456  1.108248
# 1 -0.868100  0.764036
# 2  0.253322  0.456763
# 3 -0.490970 -1.408090
# 4  0.816739 -0.779169

# %%
# hexbin plot is similar to scatter plot (bivarient var), but it can show the frequency
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# .density is same as kde plot
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
